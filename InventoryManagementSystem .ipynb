# %%
import json
import time

#created a JSON file
# data={1001:{'name':'Table','price':5500,'stock':100},
#       1002:{'name':'Chair','price':3200,'stock':100},
#       1003:{'name':'Lamp','price':1100,'stock':100},
#       1004:{'name':'Cupboard','price':1200,'stock':100},
#       1005:{'name':'pencil','price':12,'stock':100}}
# js=json.dumps(data)
# fd=open("data.json","w")
# fd.write(js)
# fd.close()

# created a JSON file
# sales={'7011060471':{'customer_name':'Aditya','customer_item':1004,'customer_bill':2400},
#        '1236547895':{'customer_name':'Rohan','customer_item':1002,'customer_bill':6400}}
# js=json.dumps(sales)
# fd=open("sales.json","w")
# fd.write(js)
# fd.close()

def menu():
  print("*************************************************")
  print("*************** Welcome to ADG store ************")
  print("*************************************************")
  print("1-->SEE ALL AVAILABLE ITEMS")
  print("2-->BUY ITEM(S)")
  print("3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)")
  print("4-->SEE SALES")
  print("5-->EXIT")
  choice=int(input("enter your choice(1/2/3)--->"))
  if choice==1:
    data()
  if choice==2:
    main()
  if choice==3:
    print("1-->ADD ITEM(S)")
    print("2-->DELETE ITEM(S)")
    choice=int(input("Enter your choice here--->"))
    if choice==1:
      add()
    if choice==2:
      delete()
    else:
      print("PLEASE ENTER A VALID CHOICE!!!")
      menu()
  if choice==4:
    sale()
  if choice==5:
    exit()


def data():
  fd = open("data.json",'r')
  r = fd.read()
  fd.close()
  data=json.loads(r)
  print("********************************** INVENTORY DATA ********************************")
  print("**********************************************************************************")
  for i in data:
    print('--->','P_ID:',i,'     ','P_NAME:',data[i]['name'],'     ','P_PRICE:',data[i]['price'],'     ','P_STOCK:',data[i]['stock'])
    print("**********************************************************************************")
  print("")
  print("")
  print("")
  menu()


def main():
  fd = open("data.json",'r')
  r = fd.read()
  fd.close()
  data = json.loads(r)

  name=input(("Please enter your name--->"))
  Pno=int(input("please enter your phone number--->"))
  id=input("enter item ID--->")
  quant=int(input("enter quantity of item(s) to buy--->"))
  print("")
  print("########################################################")
  print("####################### ADG Store ######################")
  print("###############",time.ctime(),"###############")
  print("--------------------------------------------------------")
  print('Name:',name,'               ','Mob:','(',Pno,')')
  print("NAME:",data[id]['name'],"              ","PRICE:",data[id]['price'])
  print("--------------------------------------------------------")
  print("Billing Amt:",(data[id]['price'])*quant,'(incl. of all taxes)')
  print("--------------------------------------------------------")
  print("################# THANK YOU FOR VISITING ###############")
  data[id]['stock']=data[id]['stock']-quant

  fd2 = open("sales.json",'r')
  r2 = fd2.read()
  fd2.close()
  record = json.loads(r2)
  record[str(Pno)]={'customer_name':name,'customer_item':data[id]['name'],'customer_bill':(data[id]['price'])*quant}
  js1=json.dumps(record)
  fd1=open("sales.json","w")
  fd1.write(js1)
  fd1.close()

  js=json.dumps(data)
  fd=open("data.json","w")
  fd.write(js)
  fd.close()
  print("")
  print("")
  print("")
  menu()


def add():
  for i in range(9999):
    fd = open("data.json",'r')
    r = fd.read()
    fd.close()
    data=json.loads(r)

    p_id=int(input("enter Product ID--->"))
    p_name=input("enter product name--->")
    p_price=int(input("enter product price--->"))
    p_stock=int(input("enter product stock--->"))
    data[p_id]={'name':p_name,'price':p_price,'stock':p_stock}

    js = json.dumps(data)
    fd = open("data.json",'w')
    fd.write(js)
    fd.close()
    print('')
    print("ADDED SUCESSFULLY!!!")
    print('')
    choice2=input("do you want to add more?(y/n)--->")
    if choice2=="n":
      break;
  print("")
  print("")
  print("")
  menu()


def delete():
  for i in range(9999):
    fd = open("data.json",'r')
    r = fd.read()
    fd.close()
    data=json.loads(r)

    p_id=input("enter Product ID--->")
    del data[p_id]

    js = json.dumps(data)
    fd = open("data.json",'w')
    fd.write(js)
    fd.close()
    print('')
    print("DELETED SUCESSFULLY!!!")
    print('')
    choice=input("do you want to delete more?(y/n)--->")
    if choice=='n':
      break;
  print("")
  print("")
  print("")
  menu()


def sale():
  fd = open("sales.json",'r')
  r = fd.read()
  fd.close()
  data=json.loads(r)
  print("********************************** SALES REPORT **********************************")
  print("**********************************************************************************")
  for i in data:
    print('--->','CUSTOMER_MOB:',i,'     ','CUSTOMER_NAME:',data[i]['customer_name'],'     ','CUSTOMER_BILL:',data[i]['customer_bill'])
    print("**********************************************************************************")
  print("")
  print("")
  print("")
  menu()


def exit():
  print("PLEASE VISIT AGAIN :)")


menu()
# Out:
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->1
# ********************************** INVENTORY DATA ********************************
# **********************************************************************************
# ---> P_ID: 1001       P_NAME: Table       P_PRICE: 5500       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1002       P_NAME: Chair       P_PRICE: 3200       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1003       P_NAME: Lamp       P_PRICE: 1100       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1004       P_NAME: Cupboard       P_PRICE: 1200       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1005       P_NAME: pencil       P_PRICE: 12       P_STOCK: 95
# **********************************************************************************
# ---> P_ID: 1006       P_NAME: Rice       P_PRICE: 250       P_STOCK: 197
# **********************************************************************************
# ---> P_ID: 1007       P_NAME: Cake       P_PRICE: 550       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1008       P_NAME: Toothpaste       P_PRICE: 50       P_STOCK: 250
# **********************************************************************************
# ---> P_ID: 1009       P_NAME: Cheese       P_PRICE: 54       P_STOCK: 33
# **********************************************************************************
# ---> P_ID: 1010       P_NAME: Hangar       P_PRICE: 45       P_STOCK: 230
# **********************************************************************************
# ---> P_ID: 1011       P_NAME: Bottle       P_PRICE: 50       P_STOCK: 244
# **********************************************************************************
# ---> P_ID: 1012       P_NAME: Spectacles       P_PRICE: 550       P_STOCK: 224
# **********************************************************************************
# ---> P_ID: 1013       P_NAME: rope       P_PRICE: 100       P_STOCK: 120
# **********************************************************************************
# ---> P_ID: 1014       P_NAME: Charger       P_PRICE: 420       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1015       P_NAME: Lock       P_PRICE: 450       P_STOCK: 186
# **********************************************************************************
# ---> P_ID: 1016       P_NAME: Headphone       P_PRICE: 1500       P_STOCK: 45
# **********************************************************************************
# ---> P_ID: 1017       P_NAME: Camera       P_PRICE: 42000       P_STOCK: 10
# **********************************************************************************
# ---> P_ID: 1018       P_NAME: Ball       P_PRICE: 20       P_STOCK: 35
# **********************************************************************************
# ---> P_ID: 1019       P_NAME: BoardGame       P_PRICE: 350       P_STOCK: 200
# **********************************************************************************
# ---> P_ID: 1020       P_NAME: Printer       P_PRICE: 2500       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1022       P_NAME: Pin       P_PRICE: 5       P_STOCK: 248
# **********************************************************************************
# ---> P_ID: 1023       P_NAME: Crayons       P_PRICE: 40       P_STOCK: 27
# **********************************************************************************
# ---> P_ID: 1024       P_NAME: Bowl       P_PRICE: 50       P_STOCK: 46
# **********************************************************************************
# ---> P_ID: 1025       P_NAME: HairDryer       P_PRICE: 650       P_STOCK: 30
# **********************************************************************************
# ---> P_ID: 1027       P_NAME: Bulb       P_PRICE: 65       P_STOCK: 55
# **********************************************************************************
# ---> P_ID: 1028       P_NAME: PowerBank       P_PRICE: 3500       P_STOCK: 60
# **********************************************************************************
# ---> P_ID: 1029       P_NAME: Keyboard       P_PRICE: 850       P_STOCK: 50
# **********************************************************************************
# ---> P_ID: 1030       P_NAME: Mouse       P_PRICE: 850       P_STOCK: 50
# **********************************************************************************
# ---> P_ID: 1031       P_NAME: PenDrive       P_PRICE: 450       P_STOCK: 50
# **********************************************************************************
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->2
# Please enter your name--->Rahul
# please enter your phone number--->9810364789
# enter item ID--->1031
# enter quantity of item(s) to buy--->2
#
# ########################################################
# ####################### ADG Store ######################
# ############### Sun Sep  5 20:03:32 2021 ###############
# --------------------------------------------------------
# Name: Rahul                 Mob: ( 9810364789 )
# NAME: PenDrive                PRICE: 450
# --------------------------------------------------------
# Billing Amt: 900 (incl. of all taxes)
# --------------------------------------------------------
# ################# THANK YOU FOR VISITING ###############
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->3
# 1-->ADD ITEM(S)
# 2-->DELETE ITEM(S)
# Enter your choice here--->1
# enter Product ID--->1032
# enter product name--->Diary
# enter product price--->50
# enter product stock--->250
#
# ADDED SUCESSFULLY!!!
#
# do you want to add more?(y/n)--->y
# enter Product ID--->1033
# enter product name--->ScreenGuard
# enter product price--->250
# enter product stock--->300
#
# ADDED SUCESSFULLY!!!
#
# do you want to add more?(y/n)--->n
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->3
# 1-->ADD ITEM(S)
# 2-->DELETE ITEM(S)
# Enter your choice here--->2
# enter Product ID--->1022
#
# DELETED SUCESSFULLY!!!
#
# do you want to delete more?(y/n)--->n
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->4
# ********************************** SALES REPORT **********************************
# **********************************************************************************
# ---> CUSTOMER_MOB: 7011060471       CUSTOMER_NAME: Aditya gautam       CUSTOMER_BILL: 2700
# **********************************************************************************
# ---> CUSTOMER_MOB: 1236547895       CUSTOMER_NAME: Rohan       CUSTOMER_BILL: 6400
# **********************************************************************************
# ---> CUSTOMER_MOB: 4568812544       CUSTOMER_NAME: Miller       CUSTOMER_BILL: 750
# **********************************************************************************
# ---> CUSTOMER_MOB: 2657954136       CUSTOMER_NAME: Steve       CUSTOMER_BILL: 3300
# **********************************************************************************
# ---> CUSTOMER_MOB: 7531462598       CUSTOMER_NAME: Bailey       CUSTOMER_BILL: 200
# **********************************************************************************
# ---> CUSTOMER_MOB: 1423652987       CUSTOMER_NAME: Gary       CUSTOMER_BILL: 10
# **********************************************************************************
# ---> CUSTOMER_MOB: 1038792465       CUSTOMER_NAME: Liam       CUSTOMER_BILL: 216
# **********************************************************************************
# ---> CUSTOMER_MOB: 1032687452       CUSTOMER_NAME: John       CUSTOMER_BILL: 120
# **********************************************************************************
# ---> CUSTOMER_MOB: 9810368941       CUSTOMER_NAME: Shefali       CUSTOMER_BILL: 3600
# **********************************************************************************
# ---> CUSTOMER_MOB: 2156879132       CUSTOMER_NAME: Sneha       CUSTOMER_BILL: 300
# **********************************************************************************
# ---> CUSTOMER_MOB: 3657981235       CUSTOMER_NAME: Shivam       CUSTOMER_BILL: 60
# **********************************************************************************
# ---> CUSTOMER_MOB: 4568712358       CUSTOMER_NAME: Rohan       CUSTOMER_BILL: 432
# **********************************************************************************
# ---> CUSTOMER_MOB: 9810364789       CUSTOMER_NAME: Rahul       CUSTOMER_BILL: 900
# **********************************************************************************
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->1
# ********************************** INVENTORY DATA ********************************
# **********************************************************************************
# ---> P_ID: 1001       P_NAME: Table       P_PRICE: 5500       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1002       P_NAME: Chair       P_PRICE: 3200       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1003       P_NAME: Lamp       P_PRICE: 1100       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1004       P_NAME: Cupboard       P_PRICE: 1200       P_STOCK: 100
# **********************************************************************************
# ---> P_ID: 1005       P_NAME: pencil       P_PRICE: 12       P_STOCK: 95
# **********************************************************************************
# ---> P_ID: 1006       P_NAME: Rice       P_PRICE: 250       P_STOCK: 197
# **********************************************************************************
# ---> P_ID: 1007       P_NAME: Cake       P_PRICE: 550       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1008       P_NAME: Toothpaste       P_PRICE: 50       P_STOCK: 250
# **********************************************************************************
# ---> P_ID: 1009       P_NAME: Cheese       P_PRICE: 54       P_STOCK: 33
# **********************************************************************************
# ---> P_ID: 1010       P_NAME: Hangar       P_PRICE: 45       P_STOCK: 230
# **********************************************************************************
# ---> P_ID: 1011       P_NAME: Bottle       P_PRICE: 50       P_STOCK: 244
# **********************************************************************************
# ---> P_ID: 1012       P_NAME: Spectacles       P_PRICE: 550       P_STOCK: 224
# **********************************************************************************
# ---> P_ID: 1013       P_NAME: rope       P_PRICE: 100       P_STOCK: 120
# **********************************************************************************
# ---> P_ID: 1014       P_NAME: Charger       P_PRICE: 420       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1015       P_NAME: Lock       P_PRICE: 450       P_STOCK: 186
# **********************************************************************************
# ---> P_ID: 1016       P_NAME: Headphone       P_PRICE: 1500       P_STOCK: 45
# **********************************************************************************
# ---> P_ID: 1017       P_NAME: Camera       P_PRICE: 42000       P_STOCK: 10
# **********************************************************************************
# ---> P_ID: 1018       P_NAME: Ball       P_PRICE: 20       P_STOCK: 35
# **********************************************************************************
# ---> P_ID: 1019       P_NAME: BoardGame       P_PRICE: 350       P_STOCK: 200
# **********************************************************************************
# ---> P_ID: 1020       P_NAME: Printer       P_PRICE: 2500       P_STOCK: 20
# **********************************************************************************
# ---> P_ID: 1023       P_NAME: Crayons       P_PRICE: 40       P_STOCK: 27
# **********************************************************************************
# ---> P_ID: 1024       P_NAME: Bowl       P_PRICE: 50       P_STOCK: 46
# **********************************************************************************
# ---> P_ID: 1025       P_NAME: HairDryer       P_PRICE: 650       P_STOCK: 30
# **********************************************************************************
# ---> P_ID: 1027       P_NAME: Bulb       P_PRICE: 65       P_STOCK: 55
# **********************************************************************************
# ---> P_ID: 1028       P_NAME: PowerBank       P_PRICE: 3500       P_STOCK: 60
# **********************************************************************************
# ---> P_ID: 1029       P_NAME: Keyboard       P_PRICE: 850       P_STOCK: 50
# **********************************************************************************
# ---> P_ID: 1030       P_NAME: Mouse       P_PRICE: 850       P_STOCK: 50
# **********************************************************************************
# ---> P_ID: 1031       P_NAME: PenDrive       P_PRICE: 450       P_STOCK: 48
# **********************************************************************************
# ---> P_ID: 1032       P_NAME: Diary       P_PRICE: 50       P_STOCK: 250
# **********************************************************************************
# ---> P_ID: 1033       P_NAME: ScreenGuard       P_PRICE: 250       P_STOCK: 300
# **********************************************************************************
#
#
#
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
# enter your choice(1/2/3)--->5
# PLEASE VISIT AGAIN :)
# PLEASE ENTER A VALID CHOICE!!!
# *************************************************
# *************** Welcome to ADG store ************
# *************************************************
# 1-->SEE ALL AVAILABLE ITEMS
# 2-->BUY ITEM(S)
# 3-->CHANGE INVENTORY VALUES(ONLY FOR STAFF)
# 4-->SEE SALES
# 5-->EXIT
